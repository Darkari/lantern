# %%
# %%capture
import lantern as l

# %%
df = l.bar.sample()

# %%
col1 = df.columns[0]
col2 = df.columns[1]
df
# Out:
#               JFS.YW    ODP.TF    LWP.NX    LMQ.PX    IME.GQ
# 2015-01-01  1.014424 -1.568756 -0.833527 -0.072030 -1.015740
# 2015-01-02 -0.636105 -1.669771 -1.011898  0.010382 -1.920745
# 2015-01-03 -2.334525 -1.574260 -2.257816  1.483792 -3.544133
# 2015-01-04 -1.757239 -1.268144 -0.863494  2.863074 -3.325364
# 2015-01-05 -0.889441 -1.229128 -2.452339  3.032553 -4.021555
# 2015-01-06 -0.478252  0.025631 -0.918177  1.732720 -2.173177
# 2015-01-07  0.116270  0.239436 -0.532624  2.713262 -1.613985
# 2015-01-08 -0.163170  0.335044  0.475959  2.439557 -3.015475
# 2015-01-09 -1.160274  0.418509 -1.288504  2.626046 -3.232682
# 2015-01-10 -2.724940 -0.475260 -1.620277  2.204600 -1.620147

# %%
l.plot(df, size=(12,5), subplot='y')

# %%
f = l.figure()
f.line(df[df.columns[:1]])
f.bar(df[df.columns[1:2]])
f.area(df[df.columns[1:2]])
f.show()

# %%
f = l.figure()
f.line(df[df.columns[:1]], y_axis='right')
f.bar(df[df.columns[1:2]])
f.area(df[df.columns[1:2]], y_axis='right')
f.show()
